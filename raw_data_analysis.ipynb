# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.isna().sum()
# Out:
# Unnamed: 0                            0
# Average Battery Life (in hours)    1753
# Batteries                           975
# Brand                                72
# Card Description                    922
# Chipset Brand                       297
# Color                              1138
# Computer Memory Type                279
# Flash Memory Size                   788
# Graphics Coprocessor                478
# Hard Drive                          125
# Hard Drive Interface                437
# Item Dimensions  LxWxH              568
# Item Weight                          70
# Item model number                   150
# Max Screen Resolution               293
# Memory Speed                       1048
# Number of USB 2.0 Ports            2113
# Number of USB 3.0 Ports            1796
# Operating System                    157
# Optical Drive Type                 1785
# Power Source                        956
# Processor                           129
# ...

# %%
for column in df:
    if df[column].isna().sum() > 2200:
        df = df.drop(column, axis=1)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                            0
# Average Battery Life (in hours)    1753
# Batteries                           975
# Brand                                72
# Card Description                    922
# Chipset Brand                       297
# Color                              1138
# Computer Memory Type                279
# Flash Memory Size                   788
# Graphics Coprocessor                478
# Hard Drive                          125
# Hard Drive Interface                437
# Item Dimensions  LxWxH              568
# Item Weight                          70
# Item model number                   150
# Max Screen Resolution               293
# Memory Speed                       1048
# Number of USB 2.0 Ports            2113
# Number of USB 3.0 Ports            1796
# Operating System                    157
# Optical Drive Type                 1785
# Power Source                        956
# Processor                           129
# ...

# %%
for column in df:
    print(df[column].describe())
# Out:
# count    2602.000000
# mean     1300.500000
# std       751.277024
# min         0.000000
# 25%       650.250000
# 50%      1300.500000
# 75%      1950.750000
# max      2601.000000
# Name: Unnamed: 0, dtype: float64
# count          849
# unique         101
# top       10 Hours
# freq           165
# Name: Average Battery Life (in hours), dtype: object
# count                                             1627
# unique                                              41
# top       1 Lithium ion batteries required. (included)
# freq                                               823
# Name: Batteries, dtype: object
# count     2530
# unique     132
# top         HP
# freq       652
# Name: Brand, dtype: object
# count           1680
# unique            69
# top       Integrated
# freq            1174
# Name: Card Description, dtype: object
# count      2305
# unique       30
# top       Intel
# freq       1481
# Name: Chipset Brand, dtype: object
# count      1464
# unique      210
# ...

# %%
df.to_csv('data.csv')

# %%
len(df.columns)
# Out:
# 35
